# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import matplotlib.colors as mcolors

# %%
data = pd.read_csv('lok_sabha_results_2024.csv')
df = pd.read_csv('Indian General Elections 2024.csv', encoding='latin1')
data2 = pd.read_csv('bye.csv')

# %%
print(df.shape)
df.head(10)
# Out:
# (543, 9)
#                     State/UT               Constituency  Const. No.  \
# 0  Andaman & Nicobar Islands  Andaman & Nicobar Islands           1
# 1             Andhra Pradesh            Amalapuram (SC)           7
# 2             Andhra Pradesh                 Anakapalle           5
# 3             Andhra Pradesh                 Ananthapur          19
# 4             Andhra Pradesh                 Araku (ST)           1
# 5             Andhra Pradesh               Bapatla (SC)          15
# 6             Andhra Pradesh               Chittoor(SC)          25
# 7             Andhra Pradesh                      Eluru          10
# 8             Andhra Pradesh                     Guntur          13
# 9             Andhra Pradesh                   Hindupur          20
#
#                   Leading Candidate                          Leading Party  \
# 0                   BISHNU PADA RAY                 Bharatiya Janata Party
# 1             G M HARISH (BALAYOGI)                           Telugu Desam
# 2                        C.M.RAMESH                 Bharatiya Janata Party
# 3  AMBICA G LAKSHMINARAYANA VALMIKI                           Telugu Desam
# 4                GUMMA THANUJA RANI  Yuvajana Sramika Rythu Congress Party
# 5            KRISHNA PRASAD TENNETI                           Telugu Desam
# 6            DAGGUMALLA PRASADA RAO                           Telugu Desam
# 7                PUTTA MAHESH KUMAR                           Telugu Desam
# 8       DR CHANDRA SEKHAR PEMMASANI                           Telugu Desam
# 9                 B K PARTHASARATHI                           Telugu Desam
#
#            Trailing Candidate                         Trailing Party  Margin  \
# 0          KULDEEP RAI SHARMA               Indian National Congress   24396
# 1      RAPAKA VARAPRASADA RAO  Yuvajana Sramika Rythu Congress Party  342196
# 2          BUDI MUTYALA NAIDU  Yuvajana Sramika Rythu Congress Party  296530
# 3  MALAGUNDLA SANKAR NARAYANA  Yuvajana Sramika Rythu Congress Party  188555
# 4           KOTHAPALLI GEETHA                 Bharatiya Janata Party   50580
# 5        NANDIGAM SURESH BABU  Yuvajana Sramika Rythu Congress Party  208031
# 6                REDDEPPA.N .  Yuvajana Sramika Rythu Congress Party  220479
# 7        KARUMURI SUNIL KUMAR  Yuvajana Sramika Rythu Congress Party  181857
# 8      KILARI VENKATA ROSAIAH  Yuvajana Sramika Rythu Congress Party  344695
# 9                   J SHANTHA  Yuvajana Sramika Rythu Congress Party  132427
#
#             Status
# 0  Result Declared
# 1  Result Declared
# 2  Result Declared
# 3  Result Declared
# 4  Result Declared
# 5  Result Declared
# 6  Result Declared
# 7  Result Declared
# 8  Result Declared
# 9  Result Declared

# %%
print(data.shape)
data.head(10)
# Out:
# (543, 8)
#        Constituency  Const. No.              Leading Candidate  \
# 0             AJMER          13            BHAGIRATH CHOUDHARY
# 1             ALWAR           8                BHUPENDER YADAV
# 2            AMBALA           1                 VARUN CHAUDHRY
# 3  ANANTNAG-RAJOURI           3               MIAN ALTAF AHMAD
# 4         ARAKKONAM           7              S JAGATHRATCHAKAN
# 5             ARANI          12             THARANIVENTHAN M S
# 6          Adilabad           1                   GODAM NAGESH
# 7              Agra          18          PROF S P SINGH BAGHEL
# 8    Ahmedabad East           7  HASMUKHBHAI PATEL (H.S.PATEL)
# 9    Ahmedabad West           8  DINESHBHAI MAKWANA (ADVOCATE)
#
#                          Leading Party            Trailing Candidate  \
# 0               Bharatiya Janata Party          RAMCHANDRA CHOUDHARY
# 1               Bharatiya Janata Party                   LALIT YADAV
# 2             Indian National Congress                 BANTO KATARIA
# 3  Jammu & Kashmir National Conference                MEHBOOBA MUFTI
# 4            Dravida Munnetra Kazhagam                     L VIJAYAN
# 5            Dravida Munnetra Kazhagam               GAJENDRAN, G.V.
# 6               Bharatiya Janata Party                 ATHRAM SUGUNA
# 7               Bharatiya Janata Party           SURESH CHAND KARDAM
# 8               Bharatiya Janata Party  HIMMATSINH PRAHLADSINH PATEL
# 9               Bharatiya Janata Party       BHARAT YOGENDRA MAKWANA
#
#                              Trailing Party  Margin           Status
# 0                  Indian National Congress  329991  Result Declared
# 1                  Indian National Congress   48282  Result Declared
# 2                    Bharatiya Janata Party   49036  Result Declared
# 3  Jammu & Kashmir Peoples Democratic Party  281794  Result Declared
# 4  All India Anna Dravida Munnetra Kazhagam  306559  Result Declared
# 5  All India Anna Dravida Munnetra Kazhagam  208766  Result Declared
# 6                  Indian National Congress   90652  Result Declared
# 7                           Samajwadi Party  271294  Result Declared
# 8                  Indian National Congress  461755  Result Declared
# 9                  Indian National Congress  286437  Result Declared

# %%
print(data2.shape)
data2.head(7)
# Out:
# (25, 4)
#      Constituency    State              Leading Candidate  \
# 0    Agiaon (195)    Bihar            SHIV PRAKASH RANJAN
# 1    Vijapur (26)  Gujarat               DR. C. J. CHAVDA
# 2  Porbandar (83)  Gujarat       ARJUN DEVABHAI MODHWADIA
# 3  Manavadar (85)  Gujarat     ARVINDBHAI JINABHAI LADANI
# 4  Khambhat (108)  Gujarat   CHIRAGKUMAR ARVINDBHAI PATEL
# 5  Vaghodia (136)  Gujarat  DHARMENDRASINH VAGHELA (BAPU)
# 6     KARNAL (21)  Haryana                    NAYAB SINGH
#
#                                        Leading Party
# 0  Communist Party of India  (Marxist-Leninist)  ...
# 1                             Bharatiya Janata Party
# 2                             Bharatiya Janata Party
# 3                             Bharatiya Janata Party
# 4                             Bharatiya Janata Party
# 5                             Bharatiya Janata Party
# 6                             Bharatiya Janata Party

# %%
df.describe(include=[np.number])
# Out:
#        Const. No.
# count  543.000000
# mean    18.178637
# std     16.427840
# min      1.000000
# 25%      6.000000
# 50%     14.000000
# 75%     25.000000
# max     80.000000

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Seat Distribution by Party

# %%
party_votes = data.groupby('Leading Party')['Margin'].sum().sort_values(ascending=False)
data['Margin'] = pd.to_numeric(data['Margin'], errors='coerce')
max_margin = data.loc[data['Margin'].idxmax()]
min_margin = data.loc[data['Margin'].idxmin()]

# %%
party_votes = pd.to_numeric(party_votes, errors='coerce')  
party_votes = party_votes.dropna()

if not party_votes.empty:
    leading_party_highest_votes = party_votes.idxmax()
    leading_party_lowest_votes = party_votes.idxmin()
else:
    print("No valid numeric data in party_votes.")

seats_won = data['Leading Party'].value_counts()

autopct = lambda v: f'{v:.1f}%' if v > 3 else None

plt.figure(figsize=(10, 5))
sns.barplot(x=seats_won.index, y=seats_won.values, palette='plasma')
plt.title('Number of Seats Won by Each Party')
plt.xlabel('Party')
plt.ylabel('Seats Won')
plt.xticks(rotation=90)
plt.show()


data["Leading Party"].value_counts().plot.pie(
    figsize=(6, 6),
    startangle=50,
    colors=sns.color_palette('Set2'),
    labels=None,
    autopct=autopct
)
plt.legend(labels=party_votes.index, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='x-small')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Instance of uncontested seat and two seats by same candidate

# %%
duplicate = data[data.duplicated(['Leading Candidate'], keep=False)]
duplicate
# Out:
#     Constituency  Const. No. Leading Candidate             Leading Party  \
# 430   Rae Bareli          36      RAHUL GANDHI  Indian National Congress
# 539      Wayanad           4      RAHUL GANDHI  Indian National Congress
#
#       Trailing Candidate            Trailing Party    Margin           Status
# 430  DINESH PRATAP SINGH    Bharatiya Janata Party  390030.0  Result Declared
# 539           ANNIE RAJA  Communist Party of India  364422.0  Result Declared

# %%
df2 = data[data['Status'] != 'Result Declared']
df2
# Out:
#     Constituency  Const. No.               Leading Candidate  \
# 493        Surat          24  MUKESHKUMAR CHANDRAKAANT DALAL
#
#               Leading Party Trailing Candidate Trailing Party  Margin  \
# 493  Bharatiya Janata Party                NaN            NaN     NaN
#
#           Status
# 493  Uncontested

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Vote Distribution by Party

# %%
party_votes = data.groupby('Leading Party')['Margin'].sum().sort_values(ascending=False)
print(party_votes)
# Out:
# Leading Party
# Bharatiya Janata Party                                      46081536.0
# Indian National Congress                                    13005922.0
# Dravida Munnetra Kazhagam                                    5081582.0
# All India Trinamool Congress                                 4910963.0
# Telugu Desam                                                 3660927.0
# Samajwadi Party                                              2869566.0
# Janata Dal (United)                                          1386413.0
# Shiv Sena (Uddhav Balasaheb Thackrey)                        1015430.0
# Communist Party of India (Marxist)                            746237.0
# Lok Janshakti Party(Ram Vilas)                                720603.0
# Nationalist Congress Party – Sharadchandra Pawar              716571.0
# Indian Union Muslim League                                    702660.0
# Shiv Sena                                                     700373.0
# Independent                                                   629302.0
# Jammu & Kashmir National Conference                           470210.0
# Janasena Party                                                452670.0
# Voice of the People Party                                     371910.0
# Jharkhand Mukti Morcha                                        369193.0
# Janata Dal (Secular)                                          356008.0
# All India Majlis-E-Ittehadul Muslimeen                        338087.0
# Rashtriya Janata Dal                                          336967.0
# Communist Party of India                                      334885.0
# Marumalarchi Dravida Munnetra Kazhagam                        313094.0
# Bharat Adivasi Party                                          247054.0
# Aam Aadmi Party                                               227517.0
# Asom Gana Parishad                                            222351.0
# Yuvajana Sramika Rythu Congress Party                         203915.0
# Rashtriya Lok Dal                                             196967.0
# Viduthalai Chiruthaigal Katch                                 174257.0
# Communist Party of India (Marxist-Leninist) (Liberation)      165666.0
# Aazad Samaj Party (Kanshi Ram)                                151473.0
# Revolutionary Socialist Party                                 150302.0
# Hindustani Awam Morcha (Secular)                              101812.0
# Kerala Congress                                                87266.0
# Nationalist Congress Party                                     82784.0
# AJSU Party                                                     80880.0
# Sikkim Krantikari Morcha                                       80830.0
# Zoram People’s Movement                                        68288.0
# United People’s Party, Liberal                                 51583.0
# Shiromani Akali Dal                                            49656.0
# Rashtriya Loktantrik Party                                     42225.0
# Apna Dal (Soneylal)                                            37810.0
# Name: Margin, dtype: float64

# %%
# colors = random.choices(list(mcolors.CSS4_COLORS.values()),k = 5)
# This can be used for having random slice colors for the pie chart, just change to colors = colors in plt.pie()
autopct = lambda v: f'{v:.1f}%' if v > 3 else None
plt.figure(figsize=(10, 8))
wedges, texts, autotexts = plt.pie(party_votes,labels=None,colors=sns.color_palette('Set2'), autopct= autopct, startangle=120,shadow = True, wedgeprops=dict(edgecolor='w'))
plt.title('Votes Distribution by Party', pad=40)
plt.axis('equal')

plt.legend(labels=party_votes.index, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='medium')


plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Seat Distribution Pivot Plot and Bar Graph by State

# %%
pivot_table = df.pivot_table(index='State/UT', columns='Leading Party', aggfunc='size', fill_value=0)

plt.figure(figsize=(12, 10))
pivot_table.plot(kind='bar', stacked=True, colormap='tab20b', figsize=(15, 10))
# addlabels('State/UT', seats_won)
plt.title('Seat Distribution by Party within Each State')
plt.xlabel('State/UT')
plt.ylabel('Number of Seats Won')
plt.xticks(rotation=90)
plt.legend(title='Leading Party', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_37796\1378875255.py:11: UserWarning: Glyph 150 (\x96) missing from current font.
#   plt.tight_layout()
# C:\Users\singh\AppData\Local\Temp\ipykernel_37796\1378875255.py:11: UserWarning: Glyph 146 (\x92) missing from current font.
#   plt.tight_layout()
# C:\Users\singh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\singh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
party_votes = data.groupby('Leading Party')['Margin'].sum().sort_values(ascending=False)
data['Margin'] = pd.to_numeric(data['Margin'], errors='coerce')
max_margin = data.loc[data['Margin'].idxmax()]
min_margin = data.loc[data['Margin'].idxmin()]

# %%
def addlabels(x,y):
    for i in range(36):
        plt.text(i,y[i],y[i], ha = 'center', va='bottom')

# %%
leading_party_highest_votes = party_votes.idxmax()
leading_party_lowest_votes = party_votes.idxmin()

seats_won = df['State/UT'].value_counts()

plt.figure(figsize=(10, 5))
sns.barplot(x=seats_won.index, y=seats_won.values, palette='viridis')
addlabels('State/UT', seats_won)
plt.title('Number of Constituencies by State and Union Territory')
plt.xlabel('Party')
plt.ylabel('Seats Won')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Vote Distribution by State

# %%
df['Margin'] = pd.to_numeric(df['Margin'], errors='coerce')
party_votes_statewise = df.groupby('State/UT')['Margin'].sum().sort_values(ascending=False)

# colors = random.choices(list(mcolors.CSS4_COLORS.values()),k = 5)
# This can be used for having random slice colors for the pie chart if used as an argument in plt.pie()
autopct = lambda v: f'{v:.1f}%' if v > 3 else None
plt.figure(figsize=(10, 8))
wedges, texts, autotexts = plt.pie(party_votes_statewise,labels=None,colors=sns.color_palette('Set3'), autopct= autopct, startangle=140,shadow = False, wedgeprops=dict(edgecolor='w'))
plt.title('Votes Distribution by State', pad=40)
plt.axis('equal')

plt.legend(labels=party_votes_statewise.index, loc='center left', bbox_to_anchor=(1, 0.5), fontsize='medium')
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)

plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Party vs State Heat Map

# %%
plt.figure(figsize=(11, 10))
sns.heatmap(pivot_table, annot=True, cmap='YlOrBr', fmt='d')
plt.title('Frequency of Leading Parties by State/UT')
plt.xlabel('Leading Party')
plt.ylabel('State/UT')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\singh\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.draw()
# C:\Users\singh\anaconda3\Lib\site-packages\seaborn\utils.py:80: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.draw()
# C:\Users\singh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 150 (\x96) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\singh\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 146 (\x92) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
#  <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Winning Margin Distribution Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Margin'], bins=30, kde = True)
plt.title('Distribution of Winning Margins')
plt.xlabel('Margin')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Leading and Trailing parties Seat Distribution Histogram

# %%
plt.figure(figsize=(22,10))
plt.subplot(1,2,1)
plt.xticks(rotation=90)
sns.histplot(data=data,x="Leading Party",kde=True,palette ="bright")
plt.subplot(1,2,2)
plt.xticks(rotation=90)
sns.histplot(data=data,x="Trailing Party",kde=True,palette='bright')
# Out:
# C:\Users\singh\AppData\Local\Temp\ipykernel_37796\3111005429.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=data,x="Leading Party",kde=True,palette ="bright")
# C:\Users\singh\AppData\Local\Temp\ipykernel_37796\3111005429.py:7: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=data,x="Trailing Party",kde=True,palette='bright')
# <Axes: xlabel='Trailing Party', ylabel='Count'>

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
#
# Top 5 Winning Margin Candidates

# %%
df4 = data.nlargest(5, 'Margin')
df4
# Out:
#     Constituency  Const. No.      Leading Candidate             Leading Party  \
# 221       INDORE          26        SHANKAR LALWANI    Bharatiya Janata Party
# 157       Dhubri           2        RAKIBUL HUSSAIN  Indian National Congress
# 525      VIDISHA          18  SHIVRAJ SINGH CHOUHAN    Bharatiya Janata Party
# 384      Navsari          25              C R PATIL    Bharatiya Janata Party
# 186  Gandhinagar           6              AMIT SHAH    Bharatiya Janata Party
#
#                 Trailing Candidate                     Trailing Party  \
# 221    SANJAY S/O LAKSHMAN SOLANKI                Bahujan Samaj Party
# 157       MOHAMMED BADRUDDIN AJMAL  All India United Democratic Front
# 525             PRATAPBHANU SHARMA           Indian National Congress
# 384  NAISHADHBHAI BHUPATBHAI DESAI           Indian National Congress
# 186          SONAL RAMANBHAI PATEL           Indian National Congress
#
#         Margin           Status
# 221  1175092.0  Result Declared
# 157  1012476.0  Result Declared
# 525   821408.0  Result Declared
# 384   773551.0  Result Declared
# 186   744716.0  Result Declared

# %%
width = 20
height = 8
sns.set(rc = {'figure.figsize':(width,height)})
ax = sns.barplot(data = df4, x = 'Leading Candidate', y = 'Margin', palette="ch: s=.5, r=-.5")
ax.ticklabel_format(style='plain', axis="y")

# %% [markdown]
# <span style="font-family: Arial; font-size: 20px; color: black; font-weight: bold;">
# Result of Bye Election to Assembly Constituencies

# %%
data2
# Out:
#                Constituency             State              Leading Candidate  \
# 0              Agiaon (195)             Bihar            SHIV PRAKASH RANJAN
# 1              Vijapur (26)           Gujarat               DR. C. J. CHAVDA
# 2            Porbandar (83)           Gujarat       ARJUN DEVABHAI MODHWADIA
# 3            Manavadar (85)           Gujarat     ARVINDBHAI JINABHAI LADANI
# 4            Khambhat (108)           Gujarat   CHIRAGKUMAR ARVINDBHAI PATEL
# 5            Vaghodia (136)           Gujarat  DHARMENDRASINH VAGHELA (BAPU)
# 6               KARNAL (21)           Haryana                    NAYAB SINGH
# 7          DHARAMSHALA (18)  Himachal Pradesh                  SUDHIR SHARMA
# 8       LAHAUL & SPITI (21)  Himachal Pradesh                  ANURADHA RANA
# 9             SUJANPUR (37)  Himachal Pradesh           CAPTAIN RANJIT SINGH
# 10              BARSAR (39)  Himachal Pradesh           INDER DUTT LAKHANPAL
# 11              GAGRET (42)  Himachal Pradesh                   RAKESH KALIA
# 12            KUTLEHAR (45)  Himachal Pradesh           VIVEK SHARMA (VICKU)
# 13              Gandey (31)         Jharkhand            KALPANA MURMU SOREN
# 14            Shorapur (36)         Karnataka            RAJA VENUGOPAL NAIK
# 15          BAGIDORA  (165)         Rajasthan                JAIKRISHN PATEL
# 16        Vilavancode (233)        Tamil Nadu              THARAHAI CUTHBERT
# 17  Secunderabad Cantt (71)         Telangana                      SRIGANESH
# 18             Ramnagar (7)           Tripura                 DIPAK MAJUMDER
# 19            Dadraul (136)     Uttar Pradesh             ARVIND KUMAR SINGH
# 20       Lucknow East (173)     Uttar Pradesh               O. P. SRIVASTAVA
# 21           Gainsari (292)     Uttar Pradesh             RAKESH KUMAR YADAV
# 22            Duddhi  (403)     Uttar Pradesh                    VIJAY SINGH
# 23        Bhagabangola (62)       West Bengal           REYAT HOSSAIN SARKAR
# 24          Baranagar (113)       West Bengal             SAYANTIKA BANERJEE
#
#                                         Leading Party
# 0   Communist Party of India  (Marxist-Leninist)  ...
# 1                              Bharatiya Janata Party
# 2                              Bharatiya Janata Party
# 3                              Bharatiya Janata Party
# 4                              Bharatiya Janata Party
# 5                              Bharatiya Janata Party
# 6                              Bharatiya Janata Party
# 7                              Bharatiya Janata Party
# 8                            Indian National Congress
# 9                            Indian National Congress
# 10                             Bharatiya Janata Party
# 11                           Indian National Congress
# 12                           Indian National Congress
# 13                             Jharkhand Mukti Morcha
# 14                           Indian National Congress
# 15                               Bharat Adivasi Party
# 16                           Indian National Congress
# 17                           Indian National Congress
# 18                             Bharatiya Janata Party
# 19                             Bharatiya Janata Party
# 20                             Bharatiya Janata Party
# 21                                    Samajwadi Party
# 22                                    Samajwadi Party
# 23                       All India Trinamool Congress
# 24                       All India Trinamool Congress
